# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

model = AutoModelForSeq2SeqLM.from_pretrained('facebook/nllb-200-distilled-600M')
tokenizer = AutoTokenizer.from_pretrained('facebook/nllb-200-distilled-600M')

def translate(input_text, src_lang='eng_Latn', target_lang='kan_Knda'):
    translator = pipeline(
        'translation',
        model=model,
        tokenizer=tokenizer,
        src_lang=src_lang,
        tgt_lang=target_lang,
        max_length=400
    )
    return translator(input_text)[0]['translation_text']


input_text = "Myself VIGHNESH REDDY S student of BNMIT"

# Translations
kannada = translate(input_text, target_lang='kan_Knda')
japanese = translate(input_text, target_lang='jpn_Jpan')
spanish = translate(input_text, target_lang='spa_Latn')
german = translate(input_text, target_lang='deu_Latn')
telugu = translate(input_text, target_lang='tel_Telu')

# Output
print(f"Kannada translation: {kannada}\n")
print(f"Japanese translation: {japanese}\n")
print(f"Spanish translation: {spanish}\n")
print(f"German translation: {german}\n")
print(f"Telugu translation: {telugu}\n")
# Out:
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# Kannada translation: ನಾನು ಬಿಎನ್ಎಂಐಟಿಯ ವಿಗ್ನೇಷ್ ರೆಡ್ಡಿ ವಿದ್ಯಾರ್ಥಿ
#
# Japanese translation: 私はBNMITの学生です
#
# Spanish translation: Yo mismo VIGHNESH REDDY S estudiante de BNMIT
#
# German translation: Ich selbst VIGHNESH REDDY S Student der BNMIT
#
# Telugu translation: నేను బీఎన్ఎంఐటి విద్యార్థిని
